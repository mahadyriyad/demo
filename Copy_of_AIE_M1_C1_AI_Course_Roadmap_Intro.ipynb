# %% [markdown]
# <a href="https://colab.research.google.com/github/mahadyriyad/demo/blob/main/Copy_of_AIE_M1_C1_AI_Course_Roadmap_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 AI Engineer Bootcamp - Batch 2
#
# ## 📌 Session 1: Full Course Roadmap + Introduction to Machine Learning

# %% [markdown]
# ## 🧠 AI Umbrella - Understanding the Landscape
# ![maxresdefault.jpg](data:image/jpeg;base64,...)
#
# ### 🤖 Artificial Intelligence (AI)
# ![A-futuristic-chess-match-between-a-human-grandmaster-and-a-computer-AI.webp](data:image/webp;base64,...)
# - **Definition:** Machines that mimic human intelligence.
# - **Example:** Chess-playing bots, smart assistants (like Siri).
#
# ### 📈 Machine Learning (ML)
# ![image4_v2LFcq0.max-1200x1200.png](data:image/png;base64,...)
# - **Definition:** AI that learns from data without being explicitly programmed.
# - **Example:** Spam email detection.
#
# ### 🧠 Deep Learning (DL)
# ![66a2f1efb5b625f74538bd2a_668f001243b877277fd25aa1_652ebc26fbd9a45bcec81819_Deep_Learning_vs_Machine_Learning_3033723be2.jpeg](data:image/jpeg;base64,...)
# - **Definition:** Subset of ML using neural networks with many layers.
# - **Example:** Face recognition, voice assistants.
#
# ### 🧬 Generative AI (GenAI)
# - **Definition:** Models that generate new content (text, images, code, etc.).
# - **Example:** ChatGPT, Midjourney.

# %% [markdown]
# ![llm-applications-main.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 🌍 AI Domains
#
# ### 🖼️ Computer Vision (CV)
# ![Object-detection-Real-world-applications-and-benefits.png](data:image/png;base64,...)
#
#
# ![XYSAOIAHS5SSoOZO4ge0_720Image_detection_vs_segmentation.jpg](data:image/jpeg;base64,...)
# - Teaching machines to see and interpret images/videos.
# - Example: Self-driving cars, face recognition.
#
# ### 📚 Natural Language Processing (NLP)
# ![Evolution-of-chatbots.jpg](data:image/jpeg;base64,...)
#
#
# ![What-are-AI-Voice-Agents.jpg](data:image/jpeg;base64,...)
# - Teaching machines to understand human language.
# - Example: Sentiment analysis, chatbots.

# %%
# Locally -> Vs code
# google collab

# 1. LLM ->

# %%
2+2 =4
3+3=6
4+4=8

chat gpt -> ................. (Feedback)
5+5=10

# %%
# ML  Data collection

# %% [markdown]
# Data collect -> Data clean -> Model ->

# %% [markdown]
# ## 🛤️ Course Journey Overview
#
# ### 📍 Phase 1: Machine Learning (ML)
# ![61163519cda2d290d19dc4ef_Machine Learning OG.png](data:image/png;base64,...)
# - **What is ML?**
#   - Learn from past data to make predictions/decisions.
#   - Example: Predicting house prices, classifying emails.

# %% [markdown]
# ### ⚖️ Types of ML
# - **Supervised Learning**
#   - Learn from labeled data.
#   - Example: Email = spam or not.
# - **Unsupervised Learning**
#   - Discover patterns in unlabeled data.
#   - Example: Customer segmentation.
#
# ➡️ We will explore various supervised and unsupervised algorithms step by step.

# %% [markdown]
# ### 🤖 Phase 2: Deep Learning (DL)
# - Dive into Neural Networks and Deep Architectures.
# - Real-world applications in CV & NLP.

# %% [markdown]
# ### 🔍 Phase 3: NLP and Computer Vision
# - Work on real text and image-based problems.
# - Learn tokenization, embeddings, CNNs, etc.

# %% [markdown]
# ### 🚀 Phase 4: Deployment and Showcasing
# - Learn how to deploy ML/DL models.
# - Create public URLs to showcase your projects to clients.

# %% [markdown]
# ### 🧬 Phase 5: Generative AI (GenAI)
# ![Home_ITO_Ps_5a5aac3fda.webp](data:image/webp;base64,...)
# - Introduction to LLMs and how they work.
# - How NLP tasks are handled using LLMs.
# - Work with pre-trained models.

# %% [markdown]
# ### 🔧 Model Tuning & Evaluation
# ![1_dbArqIcAHxMmZDONLdTG1A.png](data:image/png;base64,...)
# - How to evaluate model performance.
# - Fine-tuning pre-trained models for specific tasks.

# %%
1 . Opensource  , 2 . APi : Chatgpt , Gemini

Data Privacy -> Opensource (Llama , Mistral , Gemma) + Embedding Model ()

1. Cost , 2 . Latency , 3 . Deploy , 4. Monitor

# %% [markdown]
# ### 🧑‍💻 Final: AI Agents and RAG Applications
# - Learn to build AI Agents.
# - Implement Retrieval-Augmented Generation (RAG) based apps.

# %% [markdown]
# 🎯 **End Goal:** Build Real-World AI Systems, Deploy Them, and Become Industry-Ready!
